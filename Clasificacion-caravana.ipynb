# %% [markdown]
# **GITHUB:** https://github.com/Proyecto-ML/caravan-insurance-policy

# %% [markdown]
# ###############################################################################
# # **1. COMPRENSIÓN DEL NEGOCIO**
# ###############################################################################

# %% [markdown]
# ### Dataset

# %% [markdown]
# **Fuente de información:**

# %% [markdown]
# Usaremos el dataset de **INSURANCE COMPANY BENCHMARK (COIL 2000)**, el cual está disponible en:
# <br/>
# <br/>
# https://archive.ics.uci.edu/ml/datasets/Insurance+Company+Benchmark+%28COIL+2000%29
# <br/>
# <br/>
# El objetivo será predecir si un cliente está interesado o no en adquirir una póliza de seguro para caravana (casa móvil).

# %% [markdown]
# **Descripción de los datos:**

# %% [markdown]
# >Nro | Variable | Descripción | Dominio
# >--- | --- | --- | ---
# >1 | MOSTYPE | Customer Subtype [Subtipo de Cliente] | Revisar L0 (1-41: 1 High Income, expensive child, 2: Very Important Provincials, ... 40: Large family farms, 41: Mixed rurals)
# >2 | MAANTHUI | Number of houses [Nro de casas] | 1 – 10
# >3 | MGEMOMV | Avg size household [Tamaño promedio del hogar] | 1 – 6
# > 4 | MGEMLEEF | Avg age [Edad promedio] | Revisar L1 (1-6: 1: 20-30 years, 2: 30-40 years, 3: 40-50 years, 4: 50-60 years, 5: 60-70 years, 6: 70-80 years)
# >5 | MOSHOOFD | Customer main type [Tipo principal de cliente] | Revisar L2 (1-10: 1: Successful hedonists, 2: Driven Growers, 3: Average Family, 4: Career Loners, 5: Living well, 6: Cruising Seniors, 7: Retired and Religeous, 8: Family with grown ups, 9: Conservative families, 10: Farmers)
# >6 | MGODRK | Roman catholic [Católico Romano] | Revisar L3 (0-9: 0: 0%, 1: 1 - 10%, 2: 11 - 23%, 3: 24 - 36%, 4: 37 - 49%, 5: 50 - 62%, 6: 63 - 75%, 7: 76 - 88%, 8: 89 - 99%, 9: 100%)
# >7 | MGODPR | Protestant [Protestante] |
# >8 | MGODOV | Other religion [Otra religión] |
# >9 | MGODGE | No religion [No profesa religión] |
# >10 | MRELGE | Married [Casado] |
# >11 | MRELSA | Living together [Convivencia] |
# >12 | MRELOV | Other relation [Otra relación] |
# >13 | MFALLEEN | Singles [Soltero] |
# >14 | MFGEKIND | Household without children [Hogar sin hijos] |
# >15 | MFWEKIND | Household with children [Hogar con hijos] |
# >16 | MOPLHOOG | High level education [Educación de nivel alto] |
# >17 | MOPLMIDD | Medium level education [Educación de nivel medio] |
# >18 | MOPLLAAG | Lower level education [Educación de nivel bajo] |
# >19 | MBERHOOG | High status [Clase social alta] |
# >20 | MBERZELF | Entrepreneur [Empresario] |
# >21 | MBERBOER | Farmer [Granjero] |
# >22 | MBERMIDD | Middle management [Administración Intermedia] |
# >23 | MBERARBG | Skilled labourers [Trabajadores calificados] |
# >24 | MBERARBO | Unskilled labourers [Trabajadores no calificados] |
# >25 | MSKA | Social class A [Clase Social A] |
# >26 | MSKB1 | Social class B1 [Clase social B1] |
# >27 | MSKB2 | Social class B2 [Clase social B2] |
# >28 | MSKC | Social class C [Clase social C] |
# >29 | MSKD | Social class D [Clase social D]
# >30 | MHHUUR | Rented house [Casa alquilada] |
# >31 | MHKOOP | Home owners [Casa propia] |
# >32 | MAUT1 | 1 car [Propietario de 1 auto] |
# >33 | MAUT2 | 2 cars [Propietario de 2 autos] |
# >34 | MAUT0 | No car [No tiene auto] |
# >35 | MZFONDS | National Health Service [Servicio de salud público] |
# >36 | MZPART | Private health insurance [Seguro de salud privado] |
# >37 | MINKM30 | Income < 30.000 [Ingresos < 30,000] |
# >38 | MINK3045 | Income 30-45.000 [Ingresos entre 30,000 - 45,000] |
# >39 | MINK4575 | Income 45-75.000 [Ingresos entre 45,000 - 75,000] |
# >40 | MINK7512 | Income 75-122.000 [Ingresos entre 75,000 - 122,000] |
# >41 | MINK123M | Income >123.000 [Ingresos > 123,000] |
# >42 | MINKGEM | Average income [Ingresos promedio] |
# >43 | MKOOPKLA | Purchasing power class [Clase de poder adquisitivo] |
# >44 | PWAPART | Contribution private third party insurance [Contribución de seguro de terceros] | Revisar L4 (0-9: 0: f 0, 1: f 1 – 49, 2: f 50 – 99, 3: f 100 – 199, 4: f 200 – 499, 5: f 500 – 999, 6: f 1000 – 4999, 7: f 5000 – 9999, 8: f 10.000 - 19.999, 9: f 20.000 - ?)
# >45 | PWABEDR | Contribution third party insurance (firms) [Contribución de seguro de terceros (Empresas)] |
# >46 | PWALAND | Contribution third party insurane (agriculture) [Contribución de seguro de terceros (Agricultura)] |
# >47 | PPERSAUT | Contribution car policies [Contribución de pólizas de auto] |
# >48 | PBESAUT | Contribution delivery van policies [Contribución de pólizas de camioneta de despacho] |
# >49 | PMOTSCO | Contribution motorcycle/scooter policies [Contribución de pólizas de moto / scooter] |
# >50 | PVRAAUT | Contribution lorry policies [Contribución de pólizas de camión] |
# >51 | PAANHANG | Contribution trailer policies [Contribución de pólizas de trailer] |
# >52 | PTRACTOR | Contribution tractor policies [Contribución de pólizas de tractor] |
# >53 | PWERKT | Contribution agricultural machines policies [Contribución de pólizas de máquinas agrícolas] |
# >54 | PBROM | Contribution moped policies [Contribución de pólizas de ciclomotor] |
# >55 | PLEVEN | Contribution life insurances [Contribución de seguros de vida] |
# >56 | PPERSONG | Contribution private accident insurance policies [Contribución de pólizas de seguro privado de accidentes] |
# >57 | PGEZONG | Contribution family accidents insurance policies [Contribución de pólizas de seguro de accidentes familiares] |
# >58 | PWAOREG | Contribution disability insurance policies [Contribución de pólizas de seguro de invalidez] |
# >59 | PBRAND | Contribution fire policies [Contribución de pólizas de incendio] |
# >60 | PZEILPL | Contribution surfboard policies [Contribución de pólizas de tabla de surf] |
# >61 | PPLEZIER | Contribution boat policies [Contribución de pólizas de barco] |
# >62 | PFIETS | Contribution bicycle policies [Contribución de pólizas de bicicleta] |
# >63 | PINBOED | Contribution property insurance policies [Contribución de pólizas de seguro de propiedad (terreno)] |
# >64 | PBYSTAND | Contribution social security insurance policies [Contribución de pólizas de seguro social] |
# >65 | AWAPART | Number of private third party insurance [Número de seguros privados de terceros] | 1 - 12
# >66 | AWABEDR | Number of third party insurance (firms) [Número de seguros de terceros(Empresas)] |
# >67 | AWALAND | Number of third party insurane (agriculture) [Número de seguros de terceros(Agricultura)] |
# >68 | APERSAUT | Number of car policies [Número de pólizas de auto] |
# >69 | ABESAUT | Number of delivery van policies [Número de pólizas de camioneta de despacho] |
# >70 | AMOTSCO | Number of motorcycle/scooter policies [Número de pólizas de moto / scooter] |
# >71 | AVRAAUT | Number of lorry policies [Número de pólizas de camión] |
# >72 | AAANHANG | Number of trailer policies [Número de pólizas de trailer] |
# >73 | ATRACTOR | Number of tractor policies [Número de pólizas de tractor] |
# >74 | AWERKT | Number of agricultural machines policies [Número de pólizas de máquinas agrícolas] |
# >75 | ABROM | Number of moped policies [Número de pólizas de ciclomotor] |
# >76 | ALEVEN | Number of life insurances [Número de seguros de vida] |
# >77 | APERSONG | Number of private accident insurance policies [Número de pólizas de seguro privado de accidentes] |
# >78 | AGEZONG | Number of family accidents insurance policies [Número de pólizas de seguro de accidenentes familiares] |
# >79 | AWAOREG | Number of disability insurance policies [Número de pólizas de seguro de invalidez] |
# >80 | ABRAND | Number of fire policies [Número de pólizas de incendio] |
# >81 | AZEILPL | Number of surfboard policies [Número de pólizas de tabla de surf] |
# >82 | APLEZIER | Number of boat policies [Número de pólizas de barco] |
# >83 | AFIETS | Number of bicycle policies [Número de pólizas de bicicletas] |
# >84 | AINBOED | Number of property insurance policies [Número de pólizas de seguro de propiedad (terreno)] |
# >85 | ABYSTAND | Number of social security insurance policies [Número de pólizas de seguro social] |
# >86 | CARAVAN | Number of mobile home policies [Número de pólizas de caravana (casa móvil)] | 0: No adquiere póliza, 1: Adquiere póliza

# %% [markdown]
# ###############################################################################
# # **2. COMPRENSIÓN DE LOS DATOS**
# ###############################################################################

# %% [markdown]
# ### Importación de Librerías

# %%
#Librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import statsmodels.api as sm
# %matplotlib inline

# %% [markdown]
# ## **IMPORTACIÓN DE DATOS** (datasets)

# %%
#Importación del dataset de entrenamiento
#dataset_train = pd.read_csv('ticdata2000.csv',sep=',')
dataset_train = pd.read_csv('https://raw.githubusercontent.com/Proyecto-ML/caravan-insurance-policy/master/ticdata2000.csv')

# %%
#Tamaño del dataset de entrenamiento (registros, variables)
dataset_train.shape
# Out:
# (5822, 86)

# %%
#Muestra (5 registros) del dataset de entrenamiento
dataset_train.head()
# Out:
#    MOSTYPE  MAANTHUI  MGEMOMV  MGEMLEEF  ...  AFIETS  AINBOED  ABYSTAND  CARAVAN
# 0       33         1        3         2  ...       0        0         0        0
# 1       37         1        2         2  ...       0        0         0        0
# 2       37         1        2         2  ...       0        0         0        0
# 3        9         1        3         3  ...       0        0         0        0
# 4       40         1        4         2  ...       0        0         0        0
#
# [5 rows x 86 columns]

# %%
#Importación del dataset de pruebas (variables predictoras)
#dataset_test_pred = pd.read_csv('ticeval2000.csv',sep=',')
dataset_test_pred = pd.read_csv('https://raw.githubusercontent.com/Proyecto-ML/caravan-insurance-policy/master/ticeval2000.csv')

# %%
#Tamaño del dataset de pruebas (var. predictoras) 
#(registros, variables)
dataset_test_pred.shape
# Out:
# (4000, 85)

# %%
#Muestra (5 registros) del dataset de pruebas (var. predictoras)
dataset_test_pred.head()
# Out:
#    MOSTYPE  MAANTHUI  MGEMOMV  MGEMLEEF  ...  APLEZIER  AFIETS  AINBOED  ABYSTAND
# 0       33         1        4         2  ...         0       0        0         0
# 1        6         1        3         2  ...         0       0        0         0
# 2       39         1        3         3  ...         0       0        0         0
# 3        9         1        2         3  ...         0       0        0         0
# 4       31         1        2         4  ...         0       0        0         0
#
# [5 rows x 85 columns]

# %%
#Importación del dataset de pruebas (variable objetivo)
#dataset_test_labels = pd.read_csv('tictgts2000.csv',sep=',')
dataset_test_labels = pd.read_csv('https://raw.githubusercontent.com/Proyecto-ML/caravan-insurance-policy/master/tictgts2000.csv')

# %%
#Tamaño del dataset de pruebas (var. objetivo) 
#(registros, variables)
dataset_test_labels.shape
# Out:
# (4000, 1)

# %%
#Muestra (5 registros) del dataset de pruebas (var. predictoras)
dataset_test_labels.head()
# Out:
#    CARAVAN
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0

# %%
# Consolidación del dataset de pruebas (var. predictoras y var. objetivo)
dataset_test = pd.merge(dataset_test_pred, dataset_test_labels, right_index=True, left_index=True)
#dataset_test = pd.merge(dataset_test_pred, dataset_test_labels, left_on='PassengerId', right_on='PassengerId')
#dataset_test = pd.merge(dataset_test_pred, dataset_test_labels, on='PassengerId')

# %%
#Tamaño del dataset de pruebas (var. objetivo) 
#(registros, variables)
dataset_test.shape
# Out:
# (4000, 86)

# %%
#Muestra (5 registros) del dataset de pruebas consolidado
dataset_test.head()
# Out:
#    MOSTYPE  MAANTHUI  MGEMOMV  MGEMLEEF  ...  AFIETS  AINBOED  ABYSTAND  CARAVAN
# 0       33         1        4         2  ...       0        0         0        0
# 1        6         1        3         2  ...       0        0         0        1
# 2       39         1        3         3  ...       0        0         0        0
# 3        9         1        2         3  ...       0        0         0        0
# 4       31         1        2         4  ...       0        0         0        0
#
# [5 rows x 86 columns]

# %% [markdown]
# ## **ANÁLISIS EXPLORATORIO DE DATOS (AED)**

# %% [markdown]
# ### ***Análisis Univariado***

# %%
#Resumen descriptivo de las variables
dataset_train.describe()
# Out:
#            MOSTYPE     MAANTHUI  ...     ABYSTAND      CARAVAN
# count  5822.000000  5822.000000  ...  5822.000000  5822.000000
# mean     24.253349     1.110615  ...     0.014256     0.059773
# std      12.846706     0.405842  ...     0.119996     0.237087
# min       1.000000     1.000000  ...     0.000000     0.000000
# 25%      10.000000     1.000000  ...     0.000000     0.000000
# 50%      30.000000     1.000000  ...     0.000000     0.000000
# 75%      35.000000     1.000000  ...     0.000000     0.000000
# max      41.000000    10.000000  ...     2.000000     1.000000
#
# [8 rows x 86 columns]

# %%
#Tipos de datos de las variables
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 86 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOSTYPE   5822 non-null   int64
#  1   MAANTHUI  5822 non-null   int64
#  2   MGEMOMV   5822 non-null   int64
#  3   MGEMLEEF  5822 non-null   int64
#  4   MOSHOOFD  5822 non-null   int64
#  5   MGODRK    5822 non-null   int64
#  6   MGODPR    5822 non-null   int64
#  7   MGODOV    5822 non-null   int64
#  8   MGODGE    5822 non-null   int64
#  9   MRELGE    5822 non-null   int64
#  10  MRELSA    5822 non-null   int64
#  11  MRELOV    5822 non-null   int64
#  12  MFALLEEN  5822 non-null   int64
#  13  MFGEKIND  5822 non-null   int64
#  14  MFWEKIND  5822 non-null   int64
#  15  MOPLHOOG  5822 non-null   int64
#  16  MOPLMIDD  5822 non-null   int64
#  17  MOPLLAAG  5822 non-null   int64
#  18  MBERHOOG  5822 non-null   int64
#  19  MBERZELF  5822 non-null   int64
# ...

# %% [markdown]
# #### Revisión de Valores Únicos

# %%
#--------------------------------------------------
# Cantidad de Valores Únicos
#--------------------------------------------------
dataset_train.nunique()
# Out:
# MOSTYPE     40
# MAANTHUI     9
# MGEMOMV      5
# MGEMLEEF     6
# MOSHOOFD    10
#             ..
# APLEZIER     3
# AFIETS       4
# AINBOED      3
# ABYSTAND     3
# CARAVAN      2
# Length: 86, dtype: int64

# %%
#--------------------------------------------------
# % de Valores Únicos
#--------------------------------------------------
dataset_train.nunique()/len(dataset_train)
# Out:
# MOSTYPE     0.006870
# MAANTHUI    0.001546
# MGEMOMV     0.000859
# MGEMLEEF    0.001031
# MOSHOOFD    0.001718
#               ...
# APLEZIER    0.000515
# AFIETS      0.000687
# AINBOED     0.000515
# ABYSTAND    0.000515
# CARAVAN     0.000344
# Length: 86, dtype: float64

# %%
#Comentario:
#No hay variables que tengan un alto porcentaje de valores únicos (referencia: 70%)
por_val_unicos = pd.DataFrame(data = dataset_train.nunique()/len(dataset_train), columns=['Por_Val_Unico'])
por_val_unicos[por_val_unicos['Por_Val_Unico'] > 0.70].count()
# Out:
# Por_Val_Unico    0
# dtype: int64

# %%
#------------------------------------------------------
# Cantidad de Valores Únicos por columna
#------------------------------------------------------
for columna in dataset_train.columns:
    print(f'Cantidad de valores únicos de la columna {columna}: {len(dataset_train[columna].unique())}')
# Out:
# Cantidad de valores únicos de la columna MOSTYPE: 40
# Cantidad de valores únicos de la columna MAANTHUI: 9
# Cantidad de valores únicos de la columna MGEMOMV: 5
# Cantidad de valores únicos de la columna MGEMLEEF: 6
# Cantidad de valores únicos de la columna MOSHOOFD: 10
# Cantidad de valores únicos de la columna MGODRK: 10
# Cantidad de valores únicos de la columna MGODPR: 10
# Cantidad de valores únicos de la columna MGODOV: 6
# Cantidad de valores únicos de la columna MGODGE: 10
# Cantidad de valores únicos de la columna MRELGE: 10
# Cantidad de valores únicos de la columna MRELSA: 8
# Cantidad de valores únicos de la columna MRELOV: 10
# Cantidad de valores únicos de la columna MFALLEEN: 10
# Cantidad de valores únicos de la columna MFGEKIND: 10
# Cantidad de valores únicos de la columna MFWEKIND: 10
# Cantidad de valores únicos de la columna MOPLHOOG: 10
# Cantidad de valores únicos de la columna MOPLMIDD: 10
# Cantidad de valores únicos de la columna MOPLLAAG: 10
# ...

# %%
#--------------------------------------------------
# Valores Únicos por columnas
#--------------------------------------------------
for columna in dataset_train.columns:
    print(f'Valores únicos de la columna {columna}: {(dataset_train[columna].unique())}')
# Out:
# Valores únicos de la columna MOSTYPE: [33 37  9 40 23 39 11 10 41 38 22 13 31 34 24  8  7  3 36 25 20 12 35 30
#  29 32  1 26  2  4 16  5 21  6 18 27 28 17 15 19]
# Valores únicos de la columna MAANTHUI: [ 1  2  3 10  5  7  4  8  6]
# Valores únicos de la columna MGEMOMV: [3 2 4 1 5]
# Valores únicos de la columna MGEMLEEF: [2 3 1 4 5 6]
# Valores únicos de la columna MOSHOOFD: [ 8  3 10  5  9  7  2  1  6  4]
# Valores únicos de la columna MGODRK: [0 1 2 3 4 6 5 9 7 8]
# Valores únicos de la columna MGODPR: [5 4 3 2 7 1 6 9 0 8]
# Valores únicos de la columna MGODOV: [1 2 0 3 4 5]
# Valores únicos de la columna MGODGE: [3 4 5 2 6 7 0 1 9 8]
# Valores únicos de la columna MRELGE: [7 6 3 5 0 1 9 8 2 4]
# Valores únicos de la columna MRELSA: [0 2 1 6 4 3 5 7]
# Valores únicos de la columna MRELOV: [2 4 3 0 1 6 5 7 8 9]
# Valores únicos de la columna MFALLEEN: [1 0 4 2 3 5 6 7 8 9]
# Valores únicos de la columna MFGEKIND: [2 4 3 5 6 0 1 7 8 9]
# ...

# %% [markdown]
# #### Revisión de Valores Perdidos (Missings Values)

# %%
#--------------------------------------------
# Cantidad de Valores Nulos
#--------------------------------------------
dataset_train.isna().sum()
# Out:
# MOSTYPE     0
# MAANTHUI    0
# MGEMOMV     0
# MGEMLEEF    0
# MOSHOOFD    0
#            ..
# APLEZIER    0
# AFIETS      0
# AINBOED     0
# ABYSTAND    0
# CARAVAN     0
# Length: 86, dtype: int64

# %%
#--------------------------------------------
# % de Valores Nulos
#--------------------------------------------
dataset_train.isna().sum()/len(dataset_train)
# Out:
# MOSTYPE     0.0
# MAANTHUI    0.0
# MGEMOMV     0.0
# MGEMLEEF    0.0
# MOSHOOFD    0.0
#            ...
# APLEZIER    0.0
# AFIETS      0.0
# AINBOED     0.0
# ABYSTAND    0.0
# CARAVAN     0.0
# Length: 86, dtype: float64

# %%
#--------------------------------------------------
# Cantidad de Valores Nulos por columna
#--------------------------------------------------
for columna in dataset_train.columns:
    print(f'Cantidad de valores nulos de la columna {columna}: {(dataset_train[columna].isna().sum())}')
# Out:
# Cantidad de valores nulos de la columna MOSTYPE: 0
# Cantidad de valores nulos de la columna MAANTHUI: 0
# Cantidad de valores nulos de la columna MGEMOMV: 0
# Cantidad de valores nulos de la columna MGEMLEEF: 0
# Cantidad de valores nulos de la columna MOSHOOFD: 0
# Cantidad de valores nulos de la columna MGODRK: 0
# Cantidad de valores nulos de la columna MGODPR: 0
# Cantidad de valores nulos de la columna MGODOV: 0
# Cantidad de valores nulos de la columna MGODGE: 0
# Cantidad de valores nulos de la columna MRELGE: 0
# Cantidad de valores nulos de la columna MRELSA: 0
# Cantidad de valores nulos de la columna MRELOV: 0
# Cantidad de valores nulos de la columna MFALLEEN: 0
# Cantidad de valores nulos de la columna MFGEKIND: 0
# Cantidad de valores nulos de la columna MFWEKIND: 0
# Cantidad de valores nulos de la columna MOPLHOOG: 0
# Cantidad de valores nulos de la columna MOPLMIDD: 0
# Cantidad de valores nulos de la columna MOPLLAAG: 0
# ...

# %%
#Vemos los nombres de las columnas
dataset_train.columns
# Out:
# Index(['MOSTYPE', 'MAANTHUI', 'MGEMOMV', 'MGEMLEEF', 'MOSHOOFD', 'MGODRK',
#        'MGODPR', 'MGODOV', 'MGODGE', 'MRELGE', 'MRELSA', 'MRELOV', 'MFALLEEN',
#        'MFGEKIND', 'MFWEKIND', 'MOPLHOOG', 'MOPLMIDD', 'MOPLLAAG', 'MBERHOOG',
#        'MBERZELF', 'MBERBOER', 'MBERMIDD', 'MBERARBG', 'MBERARBO', 'MSKA',
#        'MSKB1', 'MSKB2', 'MSKC', 'MSKD', 'MHHUUR', 'MHKOOP', 'MAUT1', 'MAUT2',
#        'MAUT0', 'MZFONDS', 'MZPART', 'MINKM30', 'MINK3045', 'MINK4575',
#        'MINK7512', 'MINK123M', 'MINKGEM', 'MKOOPKLA', 'PWAPART', 'PWABEDR',
#        'PWALAND', 'PPERSAUT', 'PBESAUT', 'PMOTSCO', 'PVRAAUT', 'PAANHANG',
#        'PTRACTOR', 'PWERKT', 'PBROM', 'PLEVEN', 'PPERSONG', 'PGEZONG',
#        'PWAOREG', 'PBRAND', 'PZEILPL', 'PPLEZIER', 'PFIETS', 'PINBOED',
#        'PBYSTAND', 'AWAPART', 'AWABEDR', 'AWALAND', 'APERSAUT', 'ABESAUT',
#        'AMOTSCO', 'AVRAAUT', 'AAANHANG', 'ATRACTOR', 'AWERKT', 'ABROM',
#        'ALEVEN', 'APERSONG', 'AGEZONG', 'AWAOREG', 'ABRAND', 'AZEILPL',
# ...

# %% [markdown]
# #### Revisión de Variable Objetivo

# %%
#Visualizamos la cantidad de datos que hay en la columna CARAVAN
frec_abs_varobj = dataset_train["CARAVAN"].value_counts()
#print(frec_abs_varobj)
frec_rel_varobj = (dataset_train["CARAVAN"].value_counts()/dataset_train["CARAVAN"].value_counts().sum())*100
#print(frec_rel_varobj)
frec_varobj = pd.concat([frec_abs_varobj, frec_rel_varobj], axis=1)
frec_varobj.columns = ['Cantidad','%']
frec_varobj
# Out:
#    Cantidad          %
# 0      5474  94.022673
# 1       348   5.977327

# %%
#Visualizamos el histograma la columna Caravan
dataset_train["CARAVAN"].hist()

# %%
#Vemos en gráfico de barras 
fig = plt.figure()
dataset_train["CARAVAN"].value_counts().plot(kind='bar')

# %% [markdown]
# ### ***Análisis Bivariado***

# %% [markdown]
# #### Revisión de Variable Objetivo vs Variables Predictoras

# %%
#Vemos las columnas binarias
binary_columns = ['PFIETS', 'AWALAND', 'APERSONG','AGEZONG', 'AZEILPL', 'CARAVAN']

# %%
#Vemos gráficamente las columnas binarias
fig,axes = plt.subplots(3,2,figsize=(10,12))
for idx,cat_col in enumerate(binary_columns):
    row,col = idx//2,idx%2
    sns.countplot(x=cat_col,data=dataset_train,hue='CARAVAN',ax=axes[row,col])

# %% [markdown]
# #### Revisión de Variable Predictora vs Variable Predictora

# %%
#-------------------------------------
# Coeficientes de Correlación
#-------------------------------------
dataset_train.corr()
# Out:
#            MOSTYPE  MAANTHUI   MGEMOMV  ...   AINBOED  ABYSTAND   CARAVAN
# MOSTYPE   1.000000 -0.038721 -0.021997  ... -0.021087 -0.053718 -0.069385
# MAANTHUI -0.038721  1.000000  0.010102  ...  0.018304 -0.004166 -0.009809
# MGEMOMV  -0.021997  0.010102  1.000000  ...  0.025907  0.028384  0.035573
# MGEMLEEF  0.009454  0.056975 -0.328257  ... -0.020042 -0.014540  0.004491
# MOSHOOFD  0.992672 -0.045817  0.016115  ... -0.020997 -0.051723 -0.069300
# ...            ...       ...       ...  ...       ...       ...       ...
# APLEZIER -0.018162  0.000666  0.000644  ...  0.040094  0.026325  0.105700
# AFIETS   -0.015774 -0.020993  0.030330  ...  0.004845  0.009246  0.034144
# AINBOED  -0.021087  0.018304  0.025907  ...  1.000000  0.021273  0.018026
# ABYSTAND -0.053718 -0.004166  0.028384  ...  0.021273  1.000000  0.066658
# CARAVAN  -0.069385 -0.009809  0.035573  ...  0.018026  0.066658  1.000000
#
# [86 rows x 86 columns]

# %%
#---------------------------------------------------------
# Matriz de Correlación
#---------------------------------------------------------
import seaborn as sns
f, ax = plt.subplots(figsize=(18, 15))
corr = dataset_train.corr()
sns.heatmap(corr, ax=ax,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
#Vemos todas las columnas del conjunto de entrenamiento sin la columna objetivo
cols=dataset_train.columns[:-1]

# %%
#Vemos de forma gráfica la correlación que hay entre las variables del producto (seguro) 
heatMapCols=np.append(cols[-42:], np.array(['CARAVAN']))
cm = np.corrcoef(dataset_train[heatMapCols[::-1]].T)
plt.figure(figsize=(20,20))
sns.set(font_scale=1)
with sns.axes_style("white"):
    sns.heatmap(cm,yticklabels=heatMapCols[::-1],xticklabels=heatMapCols[::-1],fmt='.2f',annot_kws={'size':10},annot=True,square=True,cmap=None)

# %% [markdown]
# ###############################################################################
# # **3. PREPARACIÓN DE LOS DATOS**
# ###############################################################################

# %% [markdown]
# ## **PREPARACIÓN DE LOS DATOS (ENTRENAMIENTO)**

# %% [markdown]
# #### **PRE-PROCESAMIENTO DE DATOS**

# %%
preprocessed_dataset_train = dataset_train.copy()

# %%
dataset_train.shape
# Out:
# (5822, 86)

# %% [markdown]
# ### Eliminación de Registros Duplicados

# %%
preprocessed_dataset_train.drop_duplicates(keep="first", inplace=True)

# %%
preprocessed_dataset_train.shape
# Out:
# (5220, 86)

# %% [markdown]
# ### Eliminación de Valores Únicos

# %%
#Comentario:
#No se encontró registros con % altos de valores únicos para eliminación
#preprocessed_train_set.nunique()/len(preprocessed_train_set)
pd.DataFrame(preprocessed_dataset_train.nunique()/len(preprocessed_dataset_train))[pd.DataFrame(preprocessed_dataset_train.nunique()/len(preprocessed_dataset_train))[0] > 0.70]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %% [markdown]
# ### Eliminación de Variables Correlacionadas

# %%
#Comentario:
#No se eliminará variables correlacionadas. Se usará el método de Selección de Características "Backward Propagation" en base a la correlación

# %% [markdown]
# ### Conversión de Variables Categóricas a Numéricas / División de Variables Numéricas y Categóricas

# %%
#Comentario:
#Todas las variables son numéricas, no se requiere conversión ni división

# %% [markdown]
# ### Tratamiento de Valores Nulos

# %%
#Comentario:
#No se encontró registros con valores nulos
#preprocessed_train_set.isna().sum()/len(preprocessed_train_set)
pd.DataFrame(preprocessed_dataset_train.isna().sum()/len(preprocessed_dataset_train))[pd.DataFrame(preprocessed_dataset_train.isna().sum()/len(preprocessed_dataset_train))[0] > 0]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %% [markdown]
# ##### Eliminación de Valores Nulos

# %%
#Comentario:
#No se encontró registros con valores nulos para eliminación:
#1) Filas con Bajo % de Valores Nulos
#2) Columnas con Alto % de Valores Nulos

# %% [markdown]
# ##### Imputación (Estimación) de Valores Nulos

# %%
#Comentario:
#No se encontró registros con valores nulos para imputación

# %% [markdown]
# #### **CREACIÓN / TRANFORMACION DE CARACTERÍSTICAS**

# %%
#Comentario:
#No se creará nuevas variables

# %% [markdown]
# #### **REDUCCIÓN DE DIMENSIONALIDAD**

# %%
#nuevo_dataset=train_set.copy()
#nuevo_dataset.drop('CARAVAN', axis=1, inplace=True)
#y=train_set['CARAVAN']

preprocessed_dataset_train_X = preprocessed_dataset_train.copy()
preprocessed_dataset_train_X.drop('CARAVAN', axis=1, inplace=True)
preprocessed_dataset_train_Y = preprocessed_dataset_train['CARAVAN']

# %%
print(preprocessed_dataset_train_X.shape)
print(preprocessed_dataset_train_Y.shape)
# Out:
# (5220, 85)
# (5220,)

# %%
#====================================================================
# SELECCION DE CARACTERISTICAS (BACKWARD ELIMINATION)
#====================================================================
# Referencia:
# Feature Selection with sklearn and Pandas
# https://towardsdatascience.com/feature-selection-with-pandas-e3690ad8504b

#Adding constant column of ones, mandatory for sm.OLS model
#import statsmodels.api as sm

#X_1 = sm.add_constant(nuevo_dataset)

selec_preprocessed_dataset_train_X = sm.add_constant(preprocessed_dataset_train_X)

# %%
#Estimando sm.OLS model
#model = sm.OLS(y,X_1).fit()
#model.pvalues

model = sm.OLS(preprocessed_dataset_train_Y, selec_preprocessed_dataset_train_X).fit()
model.pvalues
# Out:
# const       0.060448
# MOSTYPE     0.175781
# MAANTHUI    0.271722
# MGEMOMV     0.862890
# MGEMLEEF    0.030110
#               ...
# AZEILPL     0.094755
# APLEZIER    0.000118
# AFIETS      0.361748
# AINBOED     0.190965
# ABYSTAND    0.227905
# Length: 86, dtype: float64

# %%
#Backward Elimination
#cols = list(nuevo_dataset.columns)
#pmax = 1
#while (len(cols)>0):
#    p= []
#    X_1 = nuevo_dataset[cols]
#    X_1 = sm.add_constant(X_1)
#    model = sm.OLS(y,X_1).fit()
#    p = pd.Series(model.pvalues.values[1:],index = cols)      
#    pmax = max(p)
#    feature_with_p_max = p.idxmax()
#    if(pmax>0.05):
#        cols.remove(feature_with_p_max)
#    else:
#        break
#selected_features_BE = cols
#print(selected_features_BE)

cols = list(preprocessed_dataset_train_X.columns)
pmax = 1
while (len(cols)>0):
    p = []
    selec_preprocessed_dataset_train_X = preprocessed_dataset_train_X[cols]
    selec_preprocessed_dataset_train_X = sm.add_constant(selec_preprocessed_dataset_train_X)
    model = sm.OLS(preprocessed_dataset_train_Y, selec_preprocessed_dataset_train_X).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['MRELGE', 'MOPLMIDD', 'MOPLLAAG', 'MBERBOER', 'MHHUUR', 'MINK123M', 'PWAPART', 'PWALAND', 'PPERSAUT', 'PLEVEN', 'PGEZONG', 'PWAOREG', 'PBRAND', 'ALEVEN', 'AGEZONG', 'APLEZIER', 'AFIETS', 'ABYSTAND']

# %%
selec_preprocessed_dataset_train_X.drop('const',axis=1, inplace=True)

# %%
selec_preprocessed_dataset_train_X.shape
# Out:
# (5220, 18)

# %%
selec_preprocessed_dataset_train_X.head()
# Out:
#    MRELGE  MOPLMIDD  MOPLLAAG  MBERBOER  ...  AGEZONG  APLEZIER  AFIETS  ABYSTAND
# 0       7         2         7         1  ...        0         0       0         0
# 1       6         5         4         0  ...        0         0       0         0
# 2       3         5         4         0  ...        0         0       0         0
# 3       5         4         2         0  ...        0         0       0         0
# 4       7         4         0         4  ...        0         0       0         0
#
# [5 rows x 18 columns]

# %% [markdown]
# ## **PREPARACIÓN DE LOS DATOS (PRUEBAS)**

# %%
preprocessed_dataset_test = dataset_test.copy()
preprocessed_dataset_test.shape
# Out:
# (4000, 86)

# %%
preprocessed_dataset_test.drop_duplicates(keep="first", inplace=True)
preprocessed_dataset_test.shape
# Out:
# (3730, 86)

# %%
#Comentario:
#No se encontró registros con % altos de valores únicos para eliminación
#preprocessed_train_set.nunique()/len(preprocessed_train_set)
pd.DataFrame(preprocessed_dataset_test.nunique()/len(preprocessed_dataset_test))[pd.DataFrame(preprocessed_dataset_test.nunique()/len(preprocessed_dataset_test))[0] > 0.70]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
#Comentario:
#No se eliminará variables correlacionadas. Se usará el método de Selección de Características "Backward Propagation" en base a la correlación

# %%
#Comentario:
#No se encontró registros con valores nulos
#preprocessed_train_set.isna().sum()/len(preprocessed_train_set)
pd.DataFrame(preprocessed_dataset_test.isna().sum()/len(preprocessed_dataset_test))[pd.DataFrame(preprocessed_dataset_test.isna().sum()/len(preprocessed_dataset_test))[0] > 0]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
#Comentario:
#No se encontró registros con valores nulos para eliminación:
#1) Filas con Bajo % de Valores Nulos
#2) Columnas con Alto % de Valores Nulos

# %%
#Comentario:
#No se encontró registros con valores nulos para imputación

# %%
#Comentario:
#No se creará nuevas variables

# %%
#Seleccion de variables en base al resultado de la estimación realizada para el conjunto de datos de entrenamiento
selec_preprocessed_dataset_test_X = preprocessed_dataset_test[['MRELGE', 'MOPLMIDD', 'MOPLLAAG', 'MBERBOER', 'MHHUUR', 'MINK123M', 'PWAPART', 'PWALAND', 'PPERSAUT', 'PLEVEN', 'PGEZONG', 'PWAOREG', 'PBRAND', 'ALEVEN', 'AGEZONG', 'APLEZIER', 'AFIETS', 'ABYSTAND']]
print(selec_preprocessed_dataset_test_X.shape)

preprocessed_dataset_test_Y = preprocessed_dataset_test['CARAVAN']
print(preprocessed_dataset_test_Y.shape)
# Out:
# (3730, 18)
# (3730,)

# %% [markdown]
# ## **DIVISIÓN DE LOS DATOS**

# %%
#Mediante el método "train_test_split" usaremos el 20% de la data para probar el modelo. El parámetro "random state" nos sirve para
#poder replicar la misma separación
#from sklearn.model_selection import train_test_split
#x_train_2, x_valid_2, y_train_2, y_valid_2 = train_test_split(selec_preprocessed_dataset_train_X, preprocessed_dataset_train_Y, test_size=0.2, random_state=0, stratify=preprocessed_dataset_train_Y)

# %%
#Comentario:
#No se usará un método de división del conjunto de datos (partición muestral de información).
#En lugar de ello, se usarán los dataset proporcionados de la siguiente manera:

# %%
# Dataset de Entrenamiento
x_train = selec_preprocessed_dataset_train_X.copy()
y_train = preprocessed_dataset_train_Y.copy()

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (5220, 18)
# (5220,)

# %%
# Dataset de Validación
x_valid = selec_preprocessed_dataset_test_X.copy()
y_valid = preprocessed_dataset_test_Y

# %%
print(x_valid.shape)
print(y_valid.shape)
# Out:
# (3730, 18)
# (3730,)

# %% [markdown]
# ###############################################################################
# # **4. MODELADO**
# ###############################################################################

# %% [markdown]
# # Naive Bayes (Algoritmo Base)

# %% [markdown]
# ### Preprocesamiento de Datos (Base)

# %%
#Tranformar la columna MOSHOOFD por 3 columnas MOSHOOFD_AF, MOSHOOFD_CL y MOSHOOFD_F
#Crear una nueva columna para customer type: Average Family
preprocessed_dataset_train["MOSHOOFD_AF"]=(preprocessed_dataset_train["MOSHOOFD"]==3).astype(int)
#Crear una nueva columna para customer type: Career Loners
preprocessed_dataset_train["MOSHOOFD_CL"]=(preprocessed_dataset_train["MOSHOOFD"]==4).astype(int)
#Crear una nueva columna para customer type: Farmers
preprocessed_dataset_train["MOSHOOFD_F"]=(preprocessed_dataset_train["MOSHOOFD"]==10).astype(int)

#Finalmente eliminar la columna MOSHOOFD
preprocessed_dataset_train.drop(["MOSHOOFD"], axis=1, inplace=True)

# %%
preprocessed_dataset_train_base = dataset_train.copy()
columna_a_eliminar={'MOSTYPE', 'MAANTHUI', 'MGEMOMV', 'MGEMLEEF', 'MGODRK', 'MGODPR', 'MGODOV', 'MGODGE', 'MRELGE', 'MRELSA', 'MFALLEEN', 'MFGEKIND', 
                      'MFWEKIND', 'MOPLLAAG', 'MBERHOOG', 'MINKM30', 'MINK3045', 'MINK4575', 'MINK7512', 'MINK123M','MBERZELF', 'MBERBOER', 'MBERMIDD', 
                      'MBERARBG', 'MBERARBO', 'MSKB1', 'MSKB2', 'MSKC', 'MSKD', 'MHHUUR', 'MHKOOP', 'MAUT1', 'MZFONDS', 'MZPART', 'PWABEDR', 'PWALAND',  
                      'PBESAUT', 'PMOTSCO', 'PVRAAUT', 'PAANHANG', 'PTRACTOR', 'PBROM', 'PLEVEN', 'PGEZONG', 'PWAOREG', 'PBRAND', 'PZEILPL', 'PPLEZIER', 
                      'PFIETS', 'PINBOED', 'AWAPART', 'AWALAND', 'APERSAUT', 'AVRAAUT', 'AAANHANG', 'ATRACTOR', 'AWERKT', 'ABROM', 'ALEVEN', 'APERSONG', 
                      'AGEZONG', 'AWAOREG', 'ABRAND', 'AZEILPL', 'AINBOED', 'ABYSTAND'}

if columna_a_eliminar.issubset(set(preprocessed_dataset_train.columns)):
    preprocessed_dataset.drop(columna_a_eliminar, axis=1, inplace=True)

if "" in preprocessed_dataset_train:
    preprocessed_dataset_train.drop([""], axis=1, inplace=True)

# %% [markdown]
# ### Modelado (Base)

# %% [markdown]
# # Árbol de clasificación

# %% [markdown]
# # Random Forest

# %% [markdown]
# # SVM

# %% [markdown]
# # Naive Bayes
